# %%
# !pip install pdfplumber nltk
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 40.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 38.9 MB/s eta 0:00:00
# ...

# %%
import os
import json
import re
import pdfplumber
import nltk
import logging
from collections import Counter

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
os.makedirs("logs", exist_ok=True)

logging.basicConfig(
    filename="logs/extraction.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# %%
PDF_DIR = "../Milestone2/papers"
OUTPUT_DIR = "extracted_sections"
COMPARE_DIR = "comparison"

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(COMPARE_DIR, exist_ok=True)

if not os.path.exists(PDF_DIR):
    raise FileNotFoundError("Milestone 2 PDFs not found. Please run Milestone 2 first.")

pdf_files = [f for f in os.listdir(PDF_DIR) if f.endswith(".pdf")]
print("PDFs found:", len(pdf_files))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1049294213.py in <cell line: 0>()
#       7
#       8 if not os.path.exists(PDF_DIR):
# ----> 9     raise FileNotFoundError("Milestone 2 PDFs not found. Please run Milestone 2 first.")
#      10
#      11 pdf_files = [f for f in os.listdir(PDF_DIR) if f.endswith(".pdf")]
#
# FileNotFoundError: Milestone 2 PDFs not found. Please run Milestone 2 first.

# %%
import os, shutil

PDF_DIR = "/content/Milestone2/papers"
os.makedirs(PDF_DIR, exist_ok=True)

for f in os.listdir("/content"):
    if f.endswith(".pdf"):
        shutil.move(f"/content/{f}", f"{PDF_DIR}/{f}")

print("PDFs ready:", os.listdir(PDF_DIR))
# Out:
# PDFs ready: ['paper1_transformers.pdf', 'paper2_bert.pdf', 'paper3_summarization.pdf']
